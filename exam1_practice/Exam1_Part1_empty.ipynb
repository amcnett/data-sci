# %% [markdown]
# ##### Exam 1 Code Practice
#
# Complete the code as instructed below for this notebook. This section of the exam is typically worth 20 points/25% of the exam 1 grade. This will help you prepare.

# %% [markdown]
# ## Pandas

# %% [markdown]
# Step 0. Place any statements needed to load necessary packages here. (2 points)

# %% [markdown]
# Step 1. Load the CSV file provided here to bring in the Pokemon data set as a dataframe. (2 points)

# %% [markdown]
# Step 2. View the first 5 records/observations. (2 points)

# %% [markdown]
# Step 3. Get basic metadata and descriptive statistics for each feature of the dataframe. (2 points)
# Hint: Code will be minimal. Just looking for two lines of code here minimally.

# %% [markdown]
# Step 4. Delete any records with missing values. (2 points) Hint: yeah, this is just one line of code. Make sure you are modifying the original dataframe.

# %% [markdown]
# Step 5. Filter the records to show only attack scores greater than 50. Store these records in a new dataframe. (3 points)

# %% [markdown]
# Step 6. Using the new dataframe from the step above, add 10 hp points to each record of the dataframe.(2 points)

# %% [markdown]
# ## Numpy

# %% [markdown]
# 1. Create a one-line NumPy statement that creates the following array [10, 20, 30, 40, 50] (1 point)

# %% [markdown]
# 2. Find the mean of that array. (1 point)

# %% [markdown]
# 3. Multiply every element in that array by 3. (1 point)

# %% [markdown]
# 4. Create a 3 x 3 matrix of ones. (1 point)

# %% [markdown]
# 5. Retrieve just the second row of ones (e.g. the middle row) (1 point)
