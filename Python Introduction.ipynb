# %% [markdown]
# # Python Overview

# %% [markdown]
# Python is an open source, general purpose programming language. It is also an intepreted language, unlike Java where we had to compile our programs before running them.
#
# A few important resources:
# * Python style guide: https://peps.python.org/pep-0008/
# * Python documentation: https://docs.python.org/3.13/
# * Python tutorial: https://runestone.academy/ns/books/published/httlads/PythonReview/python_review.html?mode=browsing
#
# ### A Few Main Differences Between Python and Java
#
# 1. No data type declaration - dynamically typed language
# 2. Semi-colons optional at end of statements
# 3. Strings can be either single or double quoted (no chars)

# %%
cost = 10  # numeric type int
tax = .06  # numeric type float
total = cost + cost * tax
print(f"Total is {total:.2f}")  # prints a string

print(type(cost))
cost = float(cost) # casting
print(type(cost))

# later you'll see sequence data types (e.g. lists) and mapping types (e.g. dictionary)
# Out:
# Total is 10.60
# <class 'int'>
# <class 'float'>

# %% [markdown]
# 4. Lose the curly braces, indentation is required in blocks (be consistent in spaces for indentation)
# 5. If statements are written as if, elif, else with colon at end of expression

# %%
print (cost > 20)  # prints bool data type

if cost > 20:  # note the quote at the end of the expression!
    tax = .07
elif cost > 15:
    tax = .06
else:
    tax = 0.0
    
total = cost + cost * tax
print(f"Total is {total:.2f}")

# %% [markdown]
# 6. Function syntax is a bit different

# %%
def calc_total(cost):  # not use of keyword "def"
    if cost > 20:
        tax = .07
    elif cost > 15:
        tax = .06
    else:
        tax = 0.0
    return cost + cost * tax

print("Total is: ", calc_total(20))

# %% [markdown]
# **Question 1**
#
# Create a function that determines if a triangle is a triangle (any 2 sides must be greater than the third)
#
# Try the following:
#
# 1, 1, 1 - triangle
#
# 1, 2, 1 - not a triangle
#
# 1, 2, 3 - not a triangle
#
# 2, 2, 3 - triangle

# %%
def isTriangle(side1, side2, side3):
    if side1 + side2 > side3 and side2 + side3 > side1 and side1 + side3 > side2:
        return True
    return False


print(isTriangle(1,1,1))
print(isTriangle(1,2,1))
print(isTriangle(1,2,3))
print(isTriangle(2,2,3))

# %% [markdown]
# 7. For loop is written more like a foreach loop

# %%
# loop to print multiples of 7

n = 0
while n < 50:
    if(n % 7 == 0):
        print (n)
    n += 1

# %%
# Loop to print multiples of 7 (for loop equivalent)
for n in range(0, 50):
    if(n % 7 == 0):
        print (n)

# %%
# Loop to print multiples of 7 (for loop equivalent)
for n in range(50):
    if(n % 7 == 0):
        print (n)

# %% [markdown]
# **Question 2**
#
# Rewrite the example above using the range function. Note that the range function comes in different forms.  Consider using the step argument.
#
# See [Built-in Function docs](https://docs.python.org/3/library/functions.html#func-range) for help.

# %%
for n in range(0, 50, 7):
    #if(n % 7 == 0):
        print (n)

# %%
# We can loop through strings as they are sequences of characters
name = "penn college"
for letter in name:
    print(letter)

# %% [markdown]
# 8. No arrays. Instead we have lists, tuples, sets, and dictionaries.
# See [list documentation]( https://docs.python.org/3/tutorial/datastructures.html).

# %%
# lists are ordered, changeable (mutable),and can have duplicate values
scores = [10, 23, 34, 90, 23]  # a list store multiple items
print("length is", len(scores)) # number of items in scores
print("first score is", scores[0]) # print first item
scores[1] = 55 # update second item

for score in scores:
    print(score)
    
missed_scores = [68, 45]
scores = scores + missed_scores
print(scores)

# %% [markdown]
# One nice aspect of working with lists in Python is that you can do **slicing**. Slicing involves using the **:** operator.  Slicing gets you a range of values.

# %%
college = "Pennsylvania College of Technology"

# get college
print(college[13:20])

# get Pennsylvania  -- slice from start
print(college[:12])

# get Technology -- slice to end
print(college[24:])

# negative indexing
# get Technology -- slice from end
print(college[-10:])

# skip letters/elements
print(college[::2])

# %% [markdown]
# **Question 3**
# Take the following string and extract the email address.
#
# sentence = "You can use et@pct.edu to email the ET School"

# %%
sentence = "You can use et@pct.edu to email the ET School"
print(sentence[12:22])
# Out:
# et@pct.edu

# %% [markdown]
# ### Lists, Tuples, Sets, and Dictionaries
#
# There are many list methods that you can use. See the [method list](https://docs.python.org/3/tutorial/datastructures.html).
#
# **Question 4**
#
# 1. Create a list of numbers
# 2. Remove first item in the list
# 3. Add two new numbers to the list
# 4. Put the list in ascending order
# 5. Show only even numbers in the list
# 6. Find max value in the list
#
# * Note about list comprehension: https://www.geeksforgeeks.org/python-list-comprehension/

# %%
scores = [99, 78, 83, 67, 96, 88]
scores
# Out:
# [99, 78, 83, 67, 96, 88]

# %%
#scores.pop(0)
del scores[0]
scores
# Out:
# [78, 83, 67, 96, 88]

# %%
scores.append(100)
scores.append(0)
scores
# Out:
# [78, 83, 67, 96, 88, 100, 0]

# %%
scores.sort()
scores
# Out:
# [0, 67, 78, 83, 88, 96, 100]

# %%
for a_score in scores:
    if a_score % 2 == 0:
        print(a_score)
# Out:
# 0
# 78
# 88
# 96
# 100

# %%
max(scores)
# Out:
# 100

# %%
# tuples are ordered and can have duplicates, but cannot change (immutable)
fruits = ("orange", "banana", "pear", "orange")
#fruits[1] = "kiwi"  # this action is not supported
fruits.add("kiwi") # this action is not supported
print(fruits)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       2 fruits = ("orange", "banana", "pear", "orange")
#       3 #fruits[1] = "kiwi"  # this action is not supported
# ----> 4 fruits.add("kiwi") # this action is not supported
#       5 print(fruits)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
# named tuples can be indexed with strings
from collections import namedtuple

Veg = namedtuple("Veg", ['cost', 'qty'])
carrot = Veg(1.99, 100)
print(carrot.cost)
# Out:
# 1.99

# %%
# sets are unordered, changeable ( can add and remove items), and do not allow duplicate values
names = {"mario", "luigi", "peach", "yoshi"}
names = {"mario", "luigi", "peach", "yoshi", "mario"} # dups are ignored
print(names)
#print(names[0]) # not indexed, cannot do this!
names.add("wario")
names.remove("luigi")
print(names)
# Out:
# {'mario', 'peach', 'yoshi', 'luigi'}
# {'mario', 'wario', 'yoshi', 'peach'}

# %% [markdown]
# **Question 5**
#
# I have a list but I want to remove duplicates. How can I use a set to do this? Hint: to create a list I can use the list() function.  To create a set I can also use the set() function.

# %%
list_dups = [10, 20, 30, 10]
list_no_dups = list(set(list_dups)) 
print(list_no_dups)
# Out:
# [10, 20, 30]

# %%
# dictionaries use key:value pairs
# dictionaries are ordered and changeable, and do not allow duplicate keys
classes = {'cit246':3, 'cit444':1, 'csc132':3}
print("credits for cit444:", classes['cit444'])
classes['csc132'] = 2
print(classes.keys())
print(classes.values())
# Out:
# credits for cit444: 1
# dict_keys(['cit246', 'cit444', 'csc132'])
# dict_values([3, 1, 2])

# %% [markdown]
# **Question 6**
#
# 1. Add another key/value pair to the dictionary.
# 2. Delete a course from the dictionary.
# 3. Sort on course name -- hint: sorted() but returns a list
# 4. Sort on credits
# 5. Loop and print only 1 credit courses

# %%
classes['cit482'] = 3
classes
# Out:
# {'cit246': 3, 'cit444': 1, 'csc132': 2, 'cit482': 3}

# %%
del classes['cit482']
classes
# Out:
# {'cit246': 3, 'cit444': 1, 'csc132': 2}

# %%
sorted(classes)
# Out:
# ['cit246', 'cit444', 'cit482', 'csc132']

# %%
for k,v in classes.items():
    if v == 1:
        print(k, v)
# Out:
# cit444 1
